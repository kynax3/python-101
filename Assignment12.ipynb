# %%
#Q1
#  The Exception class is the super class for all exceptions in Python, and it provides a number of methods and attributes that are useful 
#  for exception handling. When you create a Custom Exception by subclassing the Exception class, you inherit these methods and attributes,
#  which can be used to customize the behavior of your Custom Exception.

# %%
#Q2
def exception_hierarchy(exception_class):
    print(exception_class.__name__)
    for sub in exception_class.__subclasses__():
        exception_hierarchy(sub)
exception_hierarchy(BaseException)
# Out:
# BaseException
# Exception
# TypeError
# FloatOperation
# MultipartConversionError
# StopAsyncIteration
# StopIteration
# ImportError
# ModuleNotFoundError
# ZipImportError
# OSError
# ConnectionError
# BrokenPipeError
# ConnectionAbortedError
# ConnectionRefusedError
# ConnectionResetError
# RemoteDisconnected
# BlockingIOError
# ChildProcessError
# FileExistsError
# FileNotFoundError
# IsADirectoryError
# NotADirectoryError
# InterruptedError
# InterruptedSystemCall
# PermissionError
# ProcessLookupError
# TimeoutError
# UnsupportedOperation
# itimer_error
# herror
# gaierror
# SSLError
# SSLCertVerificationError
# SSLZeroReturnError
# SSLWantWriteError
# SSLWantReadError
# SSLSyscallError
# SSLEOFError
# Error
# SameFileError
# SpecialFileError
# ExecError
# ReadError
# URLError
# HTTPError
# ContentTooShortError
# BadGzipFile
# EOFError
# IncompleteReadError
# RuntimeError
# RecursionError
# NotImplementedError
# ZMQVersionError
# StdinNotImplementedError
# _DeadlockError
# ...

# %%
#Q3 The ArithmeticError class in Python is a built-in exception that is raised when an arithmetic operation fails.
# This can happen for several reasons, including division by zero, overflow, or underflow.
# ZeroDivisionError x=10/0
# ValueError math.sqrt(-1)

# %%
#Q4 The LookupError is a base class for all the errors that occur when a key or an index used to access a mapping or a sequence is invalid or not 
#found. It is a subclass of the Exception class.
#Two common exceptions that are subclasses of LookupError are KeyError and IndexError.
#KeyError: This exception is raised when you try to access a key that does not exist in a dictionary. 
my_dict = {'a': 1, 'b': 2, 'c': 3}
my_dict['d']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 6
#       1 #Q4 The LookupError is a base class for all the errors that occur when a key or an index used to access a mapping or a sequence is invalid or not
#       2 #found. It is a subclass of the Exception class.
#       3 #Two common exceptions that are subclasses of LookupError are KeyError and IndexError.
#       4 #KeyError: This exception is raised when you try to access a key that does not exist in a dictionary.
#       5 my_dict = {'a': 1, 'b': 2, 'c': 3}
# ----> 6 my_dict['d']
#
# KeyError: 'd'

# %%
This exception is raised when you try to access an index that is out of range in a sequence.
my_list = [1, 2, 3]
my_list[3]
# Out:
#   Cell In[4], line 1
#     This exception is raised when you try to access an index that is out of range in a sequence.
#          ^
# SyntaxError: invalid syntax

# %%
#ImportError is a built-in exception in Python that is raised when an imported module, package, or attribute cannot be found or imported properly. 
# It occurs when the import statement fails to locate the specified module or package.
# The error can occur due to several reasons such as a typo in the module name, incorrect file path, or missing dependencies.
tarting from Python 3.6, a new exception called ModuleNotFoundError was introduced to make it easier to diagnose import errors. This exception is a subclass of ImportError and is raised when a module could not be found
